# %%
conditional  statement in python are used to make decision based on condition(true/false)they control the flow of your program
types
1)if
2)if else
3)if else lader/continious if else
4)nested if else

# %%
if syntax

if condition:
    statements

# %%
age = 29
country="india"
if(age >=18 and country =="india"):
    print("eligible for voting")
# Out:
# eligible for voting

# %%
if else statement syntex

if condition:
    statemrnt of if
else:
    statement of else

# %%
age = 2
country="india"
if(age >=18 and country =="india"):
    print("eligible for voting")
else:
    print(" not eligible for voting")
# Out:
#  not eligible for voting

# %%
# write a program to check given number is even or odd
a=int(input("enter a number"))
if(a%2==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number 8
# even

# %%
# write a program to check the given number is positve , zero,negetive
if else ladder/contineous if else syntex

if condition:
    statement of condition 1
else:
    if condition2:
        statement of condition2
    else:
        if condition3:
            statement of condition3
        else:
            default statements

# %%
 # or another syntex
if condition:
    statement of condition 1
elif condition2:
    statement of condition2
elif condition3:
     statement of condition3
else:
    default statements

# %%
a=int(input("enter a number"))
if(a>0):
    print("positive")
elif(a==0):
    print("zero")
else:
    print("negetive")
# Out:
# enter a number 55
# positive

# %%
   Q # based on percentage print the result 
# 85%-100% =>distinivtion
# 60%-84% => 1st class
# 50% - 59% => second class
# >35%-49% => just pass
# <35% =>fail

# %%
a=float(input("enter % in num"))
if(a<0 or a>100):
    print("invalid number")
elif(a>85):
    print("distinivtion")
elif(a>60 and a<84):
    print("1st class")
elif(a>50 and a<59):
    print("second class")
elif(a>35 and a<49):
    print("just pass")
else:
    print("fail")
# Out:
# enter % in num 101
# invalid number

# %% [raw]
# check the given input from which type of triangle
# equilateral- three side are equal
# isolated- two side are equal
# scalene-three side are different

# %%
x=float(input("enter a value"))
y=float(input("enter a value"))
z=float(input("enter a value"))

if(x==y==z):
    print("it is equilateral")
elif(x==y or y==z or z==x):
    print("it is isolated")
else:
    print("it is scalene")
# Out:
# enter a value 2
# enter a value 2
# enter a value 2
# it is equilateral

# %% [markdown]
# question answer

# %%
1. E-commerce Discount Calculator

Scenario: An online store offers discounts based on the purchase amount:

10% discount for purchases between $100 and $500

20% discount for purchases above $500

No discount for purchases below $100


Task: Write a program that takes the purchase amount as input and calculates the discount and final amount to be paid.

# %%
a=int(input("enter the amount"))
if(a>500):
    print(a+(a*0.2),"get 20% distcount")
elif(a>100):
    print(a+(a*0.1),"get 10% distcount")
else:
    print("no discount for you")
# Out:
# enter the amount 400
# 440.0 get 10% distcount

# %% [markdown]
# 2. Traffic Light Simulation
#
# Scenario: Create a program that simulates a traffic light. The user inputs one of the colors: Red, Yellow, or Green. Based on the input:
#
# If the input is Red, display "Stop."
#
# If the input is Yellow, display "Ready to move."
#
# If the input is Green, display "Go."
#
# For invalid input, display "Invalid color."

# %%
a=str(input("enter the colour")).upper()
if(a!="RED" and a!="YELLOW" and a!="GREEN"):
    print("invalid colour")
elif(a=="RED"):
    print("stop")
elif(a=="YELLOW"):
    print("Ready to move")
else:
    print("Go.")
# Out:
# enter the colour yellow
# Ready to move

# %% [markdown]
# 3. Grade Evaluation System
#
# Scenario: A school uses the following grading system:
#
# Marks >= 90: Grade A
#
# Marks >= 75 and < 90: Grade B
#
# Marks >= 50 and < 75: Grade C
#
# Marks < 50: Fail
#
#
# Task: Write a program that accepts the student's marks and displays their grade.

# %%
a=int(input("enter your marks"))
if(a<0 or a>100):
    print("invalid number")
elif(a>90):
    print("Grade A")
elif(a>75):
    print("Grade B")
elif(a>50):
    print("Grade C")
else:
    print("fail")
# Out:
# enter your marks 101
# invalid number

# %% [markdown]
# 4. Odd or Even and Divisibility Check
#
# Scenario: Write a program that takes an integer as input and checks:
#
# Whether the number is odd or even
#
# Whether the number is divisible by 5
#
#
# Display appropriate messages for both conditions.

# %%
a=int(input("enter number"))
if(a%2==0):
     print("even")
else:
     print("odd")
print(a%5==0,"divisible by 5")
# Out:
# enter number 55
# odd
# True divisible by 5

# %% [markdown]
# 5. Password Strength Checker
#
# Scenario: Write a program that checks the strength of a password based on these rules:
#
# Length >= 8 characters: Strong
#
# Length between 5 and 7 characters: Medium
#
# Length < 5 characters: Weak

# %%
password = input("Enter your password: ")
length = len(password)

if length >= 8:
    print("Strength: Strong")
elif length >= 5: 
    print("Strength: Medium")
else:
    print("Strength: Weak")
# Out:
# Enter your password:  manishkumar
# Strength: Strong

# %% [markdown]
# 6. Electricity Bill Calculator
#
# Scenario: An electricity company charges its customers as follows:
#
# First 100 units: $0.5 per unit
#
# Next 100 units (101-200): $0.75 per unit
#
# Above 200 units: $1 per unit
#
#
# Task: Write a program that accepts the number of units consumed and calculates the total bill.

# %%
units = float(input("Enter the number of units consumed: "))
total_bill = 0

if units <= 100:
    total_bill = units * 0.5
elif units <= 200:
    total_bill = (100 * 0.5) + ((units - 100) * 0.75)
else:
    total_bill = (100 * 0.5) + (100 * 0.75) + ((units - 200) * 1.0)

print(f"Your total electricity bill is: ${total_bill:.2f}")

# %% [markdown]
# 7. Eligibility for Loan Approval
#
# Scenario: A bank approves loans based on these conditions:
#
# Age should be between 21 and 60
#
# Monthly income should be greater than or equal to $5000
#
#
# Task: Write a program to check whether a person is eligible for the loan based on their age and monthly income.

# %%
age = int(input("Enter your age: "))
income = float(input("Enter your monthly income ($): "))
if 21 <= age <= 60 and income >= 5000:
    print("Congratulations! You are eligible for the loan.")
else:
    print("Sorry, you do not meet the eligibility criteria.")
# Out:
# Enter your age:  25
# Enter your monthly income ($):  2000
# Sorry, you do not meet the eligibility criteria.

# %% [markdown]
# 8. Temperature Alert System
#
# Scenario: A weather monitoring system alerts based on the temperature:
#
# Below 0°C: "Freezing weather"
#
# 0°C to 20°C: "Cold weather"
#
# 21°C to 30°C: "Warm weather"
#
# Above 30°C: "Hot weather"
#
#
# Task: Write a program that takes the temperature as input and displays the corresponding alert message.

# %%
# Temperature Alert System
temp = float(input("Enter the temperature in °C: "))

if temp < 0:
    print("Freezing weather")
elif 0 <= temp <= 20:
    print("Cold weather")
elif 21 <= temp <= 30:
    print("Warm weather")
else:
    print("Hot weather")
# Out:
# Enter the temperature in °C:  25
# Warm weather
