# %%
error (also called exceptions) are issues that stop your program
from running properly error handling means detcting managing
those error gracefully insted of letting the program crash.

1) syntex error
2)name error
3)indent error
4)type error
5)zerodivision error
6)index error
7)value error
8)key error
9)filenotfound error

# %%
0/99
# Out:
# 0.0

# %%
syntax of exception 

try:
     # code that might cause an error
except:
    # code to handle the error

# %%
x = int(input("enter a number:"))
print(10/x)
# Out:
# enter a number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 x = int(input("enter a number:"))
# ----> 2 print(10/x)
#
# ZeroDivisionError: division by zero

# %%
try:
    x = int(input("enter a number:"))
    print(10/X)
except:
    print("oops Something went wrong")
# Out:
# enter a number: 0
# oops Something went wrong

# %%
try:
    a= int(input("enter value a:"))
    b= int(input("enter value b:"))
    c=a/b
    print("the answer of a divide by b:",c)
except ValueError:
    print("Entered value is wrong")
except ZeroDivisionError:
    print("Entered value is Zero")
except:
    print(" Something went wrong")
# Out:
# enter value a: 10
# enter value b: 5
# the answer of a divide by b: 2.0

# %%
try:
    a= int(input("enter value a:"))
    b= int(input("enter value b:"))
    c=a/b
    print("the answer of a divide by b:",c)
except(ValueError , ZeroDivisionError):
    print("please enter a valid value")
# Out:
# enter value a: 10
# enter value b: 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2     a= int(input("enter value a:"))
#       3     b= int(input("enter value b:"))
# ----> 4     c=a/d
#       5     print("the answer of a divide by b:",c)
#       6 except(ValueError , ZeroDivisionError):
#
# NameError: name 'd' is not defined
