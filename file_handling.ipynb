# %%
what is file handling?
it will allow us to create,read,write,update and delete files.
it is used to store data permanenrty /temp.

the built-in function is open() to work with files
    common modes:
* "r" = read
* "w" = write
* "a" = append
* "b" = binary
* "t" = text
* "rb" = read binary
* "wt" = write text

file path :
relative path : file name
absolute path : directories (complete loc) + file name

# %%
# absolute path:
data = open(r"C:\Users\DELL\OneDrive\Desktop\demo.txt","r")

# %%
data.read()
# Out:
# 'xjhlishdligu hdr;ofijseig;iijf;oauhfijnhbdvuoiudjdvvvdndvhjnkuhdjdjjiijvjj'

# %%
data.close()

# %%
# relative path:
d1 = open("demo.txt","r")
d1.read()
# Out:
# 'xjhlishdligu hdr;ofijseig;iijf;oauhfijnhbdvuoiudjdvvvdndvhjnkuhdjdjjiijvjj'

# %%
d1.close()

# %%
d3=open("sample1.txt","w")
d3.write("hallo manish kumar singh")
print("write done")
d3.close()
# Out:
# write done

# %%
d3=open("sample.txt","a")
d3.write("hallo manish kumar singh this is added in text ")
print("append done")
d3.close()
# Out:
# append done

# %%
import os

# %%
os.remove(r"C:\Users\DELL\OneDrive\Desktop\demo.txt")
