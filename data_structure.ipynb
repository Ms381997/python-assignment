# %%
l1=[48,'MANISH','python',32.5,True,(5+9j)]
l1
# Out:
# [48, 'MANISH', 'python', 32.5, True, (5+9j)]

# %%
l1.pop(2)
# Out:
# 'python'

# %%
l1[2]
# Out:
# 32.5

# %%
l1
# Out:
# [48, 'MANISH', 32.5, True, (5+9j)]

# %%
l1.append(True)
l1
# Out:
# [48, 'MANISH', 32.5, True, (5+9j), True]

# %%
l1.clear()
l1
# Out:
# []

# %%
del li
li
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 del l1
#       2 l1
#
# NameError: name 'l1' is not defined

# %%
nl= [2,5,9,4,7]
snl=[]
for i in nl:
    snl.append(i*i)
print (snl)
# Out:
# [4, 25, 81, 16, 49]

# %%
mnl=[2,4,1,2,5,4,1,3,8,6,6,9]
unl=[]
for i in mnl:
    if i not in unl:
        unl.append(i)
print(unl)
# Out:
# [2, 4, 1, 5, 3, 8, 6, 9]

# %%
# o/p =[3,9,9,4,10]
l1=[2,5,3,1,2]
l2=[1,4,6,3,8]
l3=[]
for i in range(0,len(l1),1):
    l3.append(l1[i]+l2[i])
l3
# Out:
# [3, 9, 9, 4, 10]

# %%
x1 =[1,2,3,4,5]
x2=[4,5,6,7,8]
o/p
o1=[1,2,3,4,5,6,7,8]
o2=[1,2,3]
o3=[6,7,8]
o4=[4,5]
o5= [1,2,3,6,7,8]

# %%
x1 =[1,2,3,4,5]
x2=[4,5,6,7,8]
o2=[]
for i in x1:
    if i not in x2:
        o2.append(i)
o2
# Out:
# [1, 2, 3]

# %%
x1 =[1,2,3,4,5]
x2=[4,5,6,7,8]
o1=x1
for i in x1:
    if i not in o1:
        o1.append(i)
o1
# Out:
# [1, 2, 3, 4, 5]

# %%
list slicing
syntax:-
var[start_pos:stop_pos:step_size]

default:
*start_value : 0
*stop_value : upto end
*step_size : 1

# %%
list1=[27,"python",25.8,False,12,3+5j,"java"]
list1
# Out:
# [27, 'python', 25.8, False, 12, (3+5j), 'java']

# %%
list1[:4:1]
# Out:
# [27, 'python', 25.8, False]

# %%
list1[4:7:1]
# Out:
# [12, (3+5j), 'java']

# %%
# last 3 value
list1[-3:]
# Out:
# [12, (3+5j), 'java']

# %%
# extract odd position index element
list1[0::2]
# Out:
# [27, 25.8, 12, 'java']

# %%
# print reversed list
list1[::-1]
# Out:
# ['java', (3+5j), 12, False, 25.8, 'python', 27]

# %%
x=[]
for i in range(len(list1)-1,-1,-1):
    rev.append(list1[i])
rev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 x=[]
#       2 for i in range(len(list1)-1,-1,-1):
# ----> 3     rev.append(list1[i])
#       4 rev
#
# NameError: name 'rev' is not defined

# %%
list2=[3,8,56,12,30,25,1,49]
list2
# operation:-
# sum
# max
# min
# count
# avg
# Out:
# [3, 8, 56, 12, 30, 25, 1, 49]

# %%
sum(list2)
# Out:
# 184

# %%
max(list2)
# Out:
# 56

# %%
min(list2)
# Out:
# 1

# %%
len(list2)
# Out:
# 8

# %%
mean = sum(list2)/len(list2)
mean
# Out:
# 23.0

# %%
list3=[3,8,56,12,3,30,25,1,49]
list3
# Out:
# [3, 8, 56, 12, 3, 30, 25, 1, 49]

# %%
list3.count(3)
# Out:
# 2

# %%
l1=["m","na","i","ke"]
l2=["y","me","s","lly"]
l3=[]
for i in range(0,len(l1),1):
    l3.append(l1[i]+l2[i])
l3
# Out:
# ['my', 'name', 'is', 'kelly']

# %%
l1=[23,49,67,10,33,89,75,52,83,43,12,14]
# create 3 equal chunks
n=len(l1)//3
c1=l1[0:n]
c2=l1[n:len(l1)-n]
c3=l1[len(l1)-n:]
print(c1,c2,c3)
# Out:
# [23, 49, 67, 10] [33, 89, 75, 52] [83, 43, 12, 14]

# %%
tuple:
its represented by () or tuple()

*its multivalused variable it can store all the datatypes data 
*its immutable in nature 
*its ordered 
*it allow duplicate values

# %%
t1 = (12,"programing",45.2,True,(9+3j),32)
t1
# Out:
# (12, 'programing', 45.2, True, (9+3j), 32)

# %%
t1.append("manish")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 t1.append("manish")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
temp_list = list(t1)
temp_list
# Out:
# [12, 'programing', 45.2, True, (9+3j), 32]

# %%
temp_list[3]=False
temp_list
# Out:
# [12, 'programing', 45.2, False, (9+3j), 32]

# %%
t1=tuple(temp_list)
t1
# Out:
# (12, 'programing', 45.2, False, (9+3j), 32)

# %%
import math
tp1=(3,6,1,8,9,4)
sqtp1=[]
for i in tp1:
    sqtp1.append(math.sqrt(i))
otp=tuple(sqtp1)
print(otp)
# Out:
# (1.7320508075688772, 2.449489742783178, 1.0, 2.8284271247461903, 3.0, 2.0)

# %%
set:
    its also multivalued variable can hold all datatypes data
*its repesented by {| or set()
*its mutable in nature 
*its unordered
*it wont allow you to add duplicate data

# %%
s1={12, 'programing', 45.2, False, (9+3j), 32}
s1
# Out:
# {(9+3j), 12, 32, 45.2, False, 'programing'}

# %%
s1.add(100)
s1
# Out:
# {(9+3j), 100, 12, 32, 45.2, False, 'java', 'programing'}

# %%
s1.add("java")
s1
# Out:
# {(9+3j), 100, 12, 32, 45.2, False, 'java', 'programing'}

# %%
s1.remove(100)
s1
# Out:
# {(9+3j), 12, 32, 45.2, False, 'java', 'programing'}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
o/p
o1={1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s2.difference(s1)
# Out:
# {6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 6, 7, 8}
